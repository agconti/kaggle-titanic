# %% [markdown]
# ##Kaggle Competition | Titanic Machine Learning from Disaster
# ####Goal for this Notebook:
# Show a simple example of an analysis of the Titanic disaster in Python using a full complement <br />
# of PyData utiltites. This is aimed for those looking to get into the field or those who are already <br />
# in the field and looking to see an example of an analysis done with Python.
# <br />
# <br />
# ####This Notebook will show basic examples of:
# <br />
# ####Data Handleing
# *	Importing Data with Pandas
# *	Cleaning Data
# *	Exploring Data Through Visualizations with Matplotlib
#
# ####Data Analsysis
# *	 Supervised Machine learning Technique:
#     +	Logit Regression Model
#     +	Plotting results
# *	Unsupervised Machine learning Techniques
#     +	Support Vecotr Machine (SVM) using 3 kernels
#     +	Plotting results
#
# ####Valuation of the Analysis
# *	K-folds cross validation to valuate results locally
# *	Output the results from the Ipython Notebook
#
# <br />
# <br />
# ####Required Libraries:
# * NumPy
# * Pandas
# * SciKit-Learn
# * SciPy
# * StatsModels
# * Patsy
# * Matplotlib

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.nonparametric import KDE, smoothers_lowess
from scipy import *
from pandas import Series,DataFrame
from patsy import dmatrices

import pylab as pl
from sklearn import datasets, svm

#cd r'C:\Users\Andrew\Documents\Kaggle\\Titanic\Dups/'
#plt.figsize(8,8)

# %%
#bring in some of my own custom functions
import sys
sys.path.append('C:\Users\Andrew\Documents\Kaggle\Kaggel Aux')
import kaggelaux as ka

# %% [markdown]
# ## Data Handleing
# ###Lets Read Our data in Using Pandas:

# %%
df = pd.read_csv("Train.csv")

# %% [markdown]
# ### Lets take a look:

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 9 columns):
# survived    712  non-null values
# pclass      712  non-null values
# name        712  non-null values
# sex         712  non-null values
# age         712  non-null values
# sibsp       712  non-null values
# parch       712  non-null values
# fare        712  non-null values
# embarked    712  non-null values
# dtypes: float64(2), int64(4), object(3)

# %%
df = df.drop(['ticket','cabin'], axis=1)

# %%
#take care of nans in age
df = df.dropna()

# %%
fig = plt.figure(figsize(16,6), dpi=300)
a = 0.2

plt.subplot2grid((2,3),(0,0))
df.survived.value_counts().plot(kind='bar')
title("Distribution of Survival, (1 = Survived)")

plt.subplot2grid((2,3),(0,1))
plt.scatter(df.survived, df.age, alpha=a)
plt.ylabel("Age")
title("Survial by Age,  (1 = Survived)")

plt.subplot2grid((2,3),(0,2))
df.pclass.value_counts().plot(kind="barh")
#plt.xlabel("Predicted chance of survival")
#plt.ylabel("Age")
title("Class Distribution")

plt.subplot2grid((2,3),(1,0), colspan=2)
df.age[df.pclass == 1].plot(kind='kde')
df.age[df.pclass == 2].plot(kind='kde')
df.age[df.pclass == 3].plot(kind='kde')
plt.xlabel("Age")
title("Age Distribution within classes"); legend(('1st Class', '2nd Class','3rd Class'),loc='best')

plt.subplot2grid((2,3),(1,2))
df.embarked.value_counts().plot(kind='bar')
title("Passengers per boarding location"); legend(('Embarked C', 'Embarked S','Embarked Q'),loc='best')

# %% [markdown]
# ###Explorator Visualization:
#
# The point of this comepetion is to predict if an induvidual will survive based on the test data, ie. Class, Sex, Age, Fare Price ect.
# Lets see if we can gain a better Understanding of who survied and died.
# <br />
# <br />
# First lets plot a bar graph of those who Survived Vs. Those who did not.

# %%
#are there two unique distributions? Yeah
plt.figure(figsize(6,4))
df.survived.value_counts().plot(kind='barh', color="blue", alpha=.65)
title("Survival Breakdown (1 = Survived, 0 = Died)")

# %% [markdown]
# ###Now let’s tease more structure out of the data,
# ###Let’s break the previous graph down by gender

# %%
#Are they male and female?
plt.figure(figsize(6,4))
df.survived[df.sex == 'male'].value_counts().plot(kind='barh',label='Male')
df.survived[df.sex == 'female'].value_counts().plot(kind='barh', color='#FA2379',label='Female')
title("Who Survied? with respect to Gender"); legend(loc='best')

# %% [markdown]
# should be adjusted for % of gender in pop. yes more males in raw number surived but not percentage

# %% [markdown]
# ###Great! But Lets Go down even further:
# ###Break it down by Gender and What Class they were travling in

# %%
#same realtionship between the two. but yes bumps are mostly male sur v female surv
# is the bump class? here we will bucket classes as lowest class or any of the high classes. 3 is lowest class
# building on the previous code
fig=plt.figure(figsize=(20,6))
#title("Who Survied? with respect to Gender and Class")
a=.65 # our alpha or opacity level.

ax1=fig.add_subplot(141)
df.survived[df.sex == 'female'][df.pclass != 3].value_counts().plot(kind='bar', label='female highclass', color='#FA2479', alpha=a)
ax1.set_xticklabels(["Survived", "Died"], rotation=0)
title("Who Survied? with respect to Gender and Class"); legend(loc='best')


ax2=fig.add_subplot(142, sharey=ax1)
df.survived[df.sex == 'female'][df.pclass == 3].value_counts().plot(kind='bar', label='female, low class', color='pink', alpha=a)
ax2.set_xticklabels(["Died","Survived"], rotation=0)
legend(loc='best')

ax3=fig.add_subplot(143, sharey=ax1)
df.survived[df.sex == 'male'][df.pclass == 3].value_counts().plot(kind='bar', label='male, low class',color='lightblue', alpha=a)
ax3.set_xticklabels(["Died","Survived"], rotation=0)
legend(loc='best')

ax4=fig.add_subplot(144, sharey=ax1)
df.survived[df.sex == 'male'][df.pclass != 3].value_counts().plot(kind='bar', label='male highclass', alpha=a, color='steelblue')
ax4.set_xticklabels(["Died","Survived"], rotation=0)
legend(loc='best')

# %% [markdown]
# ### This is a typical process in interactive data analysis. First you start small and understand the most basic relationships and slowly increment the complexity of your analysis as you discover more and more about the data you’re working with. Below is the progression of process laid out together:

# %%
fig=plt.figure(figsize(20,12))
a=0.65

fig.add_subplot(341)
df.survived.value_counts().plot(kind='bar', color="blue", alpha=a)
title("Step. 1")

fig.add_subplot(345)
#Are they male and female?
df.survived[df.sex == 'male'].value_counts().plot(kind='bar',label='Male')
df.survived[df.sex == 'female'].value_counts().plot(kind='bar', color='#FA2379',label='Female')
title("Step. 2"); legend(loc='best')

ax1=fig.add_subplot(349)
df.survived[df.sex == 'female'][df.pclass != 3].value_counts().plot(kind='bar', label='female highclass', color='#FA2479', alpha=a)
ax1.set_xticklabels(["Survived", "Died"], rotation=0)
title("Step. 3"); legend(loc='best')


ax2=fig.add_subplot(3,4,10, sharey=ax1)
df.survived[df.sex=='female'][df.pclass==3].value_counts().plot(kind='bar', label='female, low class', color='pink', alpha=a)
ax2.set_xticklabels(["Died","Survived"], rotation=0)
legend(loc='best')

ax3=fig.add_subplot(3,4,11, sharey=ax1)
df.survived[df.sex == 'male'][df.pclass == 3].value_counts().plot(kind='bar', label='male, low class',color='lightblue', alpha=a)
ax3.set_xticklabels(["Died","Survived"], rotation=0)
legend(loc='best')

ax4=fig.add_subplot(3,4,12, sharey=ax1)
df.survived[df.sex == 'male'][df.pclass != 3].value_counts().plot(kind='bar', label='male highclass', alpha=a, color='steelblue')
ax4.set_xticklabels(["Died","Survived"], rotation=0)
legend(loc='best')

# %% [markdown]
# #### Now that we have a basic understanding of What we are trying to predict, lets predict it.
# ####Lets run some regressions:

# %% [markdown]
# ###Supervised Machine Learning
# ####Logistic Regresion

# %%
df.columns
# Out:
# Index([survived, pclass, name, sex, age, sibsp, parch, fare, embarked], dtype=object)

# %% [markdown]
# ran with out pclass becuase it and fare must be mutilcol res= 7799, which is just with bench mark

# %%
#model formula
formula = 'survived ~ C(pclass) + C(sex) + age + sibsp  + C(embarked)'
results = {}

# %%
y,x = dmatrices(formula, data=df, return_type='dataframe')
model = sm.Logit(y,x)
res = model.fit()

results['Logit'] = [res, formula]
res.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 316.404460
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      704
# Method:                           MLE   Df Model:                            7
# Date:                Sun, 19 May 2013   Pseudo R-squ.:                  0.3414
# Time:                        22:55:25   Log-Likelihood:                -316.40
# converged:                       True   LL-Null:                       -480.45
#                                         LLR p-value:                 5.992e-67
# ====================================================================================
#                        coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept            4.5423      0.474      9.583      0.000         3.613     5.471
# C(pclass)[T.2]      -1.2673      0.299     -4.245      0.000        -1.852    -0.682
# C(pclass)[T.3]      -2.4966      0.296     -8.422      0.000        -3.078    -1.916
# C(sex)[T.male]      -2.6239      0.218    -12.060      0.000        -3.050    -2.197
# C(embarked)[T.Q]    -0.8351      0.597     -1.398      0.162        -2.006     0.335
# C(embarked)[T.S]    -0.4254      0.271     -1.572      0.116        -0.956     0.105
# age                 -0.0436      0.008     -5.264      0.000        -0.060    -0.027
# sibsp               -0.3697      0.123     -3.004      0.003        -0.611    -0.129
# ====================================================================================
# """

# %% [markdown]
# # How did we do?

# %% [markdown]
# ### Lets Look at our predictions graphically:

# %%
fig = plt.figure(figsize(21,8), dpi=300)
a = .2

fig.add_subplot(221)
kde_res = KDE(res.predict())
kde_res.fit()
plt.plot(kde_res.support,kde_res.density)
plt.fill_between(kde_res.support,kde_res.density, alpha=a)
title("Distribution of our Predictions")

fig.add_subplot(222)
#kde_gender=KDE(x['sex[T.male]']
plt.scatter(res.predict(),x['C(sex)[T.male]'] , alpha=a)
plt.xlabel("Predicted chance of survival")
plt.ylabel("Gender Bool")
title("The Change of Survival Probability by Gender (1 = Male)")

fig.add_subplot(223)
plt.scatter(res.predict(),x['C(pclass)[T.3]'] , alpha=a)
plt.xlabel("Predicted chance of survival")
plt.ylabel("Class Bool")
title("The Change of Survival Probability by Lower Class (1 = 3rd Class)")

fig.add_subplot(224)
plt.scatter(res.predict(),x.age , alpha=a)
title("The Change of Survival Probability by Age")
plt.xlabel("Predicted chance of survival")
plt.ylabel("Age")

# %%
lowess = smoothers_lowess.lowess(res.predict(),np.linspace(0,1,len(res.predict())/1))

# %%
plt.figure(figsize(8,6))
plt.scatter(res.predict(),np.linspace(0,1,len(res.predict())/1), alpha=.6)
plt.plot(lowess[:,0],lowess[:,1], lw=2, label='Lowess Fit', color='r'); legend(loc='best')

# %%
test_data = pd.read_csv("test.csv")

# %%
test_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 10 columns):
# pclass      418  non-null values
# name        418  non-null values
# sex         418  non-null values
# age         332  non-null values
# sibsp       418  non-null values
# parch       418  non-null values
# ticket      418  non-null values
# fare        417  non-null values
# cabin       91  non-null values
# embarked    418  non-null values
# dtypes: float64(2), int64(3), object(5)

# %%
# add our y to our test data
test_data['survived'] = 1.23

# %%
results
# Out:
# {'Logit': [<statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x1f9eb400>,
#   'survived ~ C(pclass) + C(sex) + age + sibsp  + C(embarked)']}

# %%
compared_resuts = ka.predict(test_data, results, 'Logit') # Use your model to make prediction on our test set.

# %%
# output and submit to kaggel
compared_resuts.to_csv("logitregres.csv")

# %% [markdown]
# ### Results = 0.77033

# %% [markdown]
# Needs imporvement

# %%
compared_resuts # theres NaNs and their shouldnt be
# Out:
# array([-2.91883597, -0.80037361, -2.88951475, -2.18185039,  0.29053579,
#        -1.6145775 , -0.09855878, -1.27860165,  1.26020428, -2.65945053,
#                nan, -0.51429876,  2.74354219, -2.89314757,  1.69626917,
#         1.85799838, -1.7113326 , -1.49461834,  0.07235391,  0.08202213,
#        -0.85132155, -1.39639562,         nan,  1.00202443,  2.07804658,
#        -3.55519624,  3.58230155, -1.56007291, -0.29611688,         nan,
#        -2.32587468, -1.5610381 , -0.18946435,         nan,  0.23958785,
#        -1.3855274 ,         nan,  0.70388137, -2.09457764,         nan,
#        -2.28007311,         nan, -2.79275965,  1.54047554,  1.78354192,
#        -2.09457764, -0.04524859,         nan,  1.92411927,  0.04933573,
#         0.07599231, -0.52711504,  1.2374209 ,  1.78594191,         nan,
#        -3.32858156, -2.5309414 , -2.09457764,         nan,  2.97139229,
#        -1.74548663, -1.17071071, -1.789123  ,  0.25053223,  0.61169704,
#                nan,  0.42507773, -0.55793513,  0.56566067,  1.12899628,
#         0.16325948, -1.92003213,  0.35479036,  0.67475161,  3.01502867,
#         0.50020611,         nan,  0.97746896, -1.08343796,  0.16325948,
#        -1.20978191, -1.80037185, -0.64520788,         nan,         nan,
#                nan,  0.03235035,  0.83479049,         nan, -0.23132863,
#         0.29053579,         nan,  2.56899669,         nan,  0.82747893,
#        -2.09457764,  0.43081426, -2.26912314,  0.74751774, -2.44366864,
#         2.29622846, -1.32223803,         nan, -2.13821401,  0.97776783,
#        -2.22548676, -2.32974489,         nan,         nan, -0.58161963,
#        -1.13802431,         nan,  2.97139229,  0.40325955,  0.99808715,
#        -1.73341842,         nan,  1.20689968,  0.34747879,  1.21440272,
#         2.32593031,         nan,  2.64531946, -2.22548676,         nan,
#         0.87842687, -1.96366851,         nan, -1.60707447, -2.05094126,
#        -2.40003227, -0.3943396 ,         nan,         nan, -2.8800324 ,
#        -2.05094126, -1.73461841, -0.90889245,  0.61660861, -3.11883248,
#        -0.6646645 ,  2.67688763, -1.11313981, -0.99616521, -0.33975325,
#        -3.4655235 ,         nan, -1.96366851,         nan, -1.45314716,
#         3.53866518,         nan, -3.64366898,  0.04933573, -3.04977793,
#        -2.05094126,  2.85143313,  0.61660861, -0.33975325,  0.48569949,
#                nan, -1.25341828,  1.71502105,         nan, -1.56343809,
#         0.11599029, -0.17615772, -2.52854141,         nan,  0.66024499,
#                nan, -1.7564366 , -2.37701408,         nan, -3.11883248,
#         2.19502118,  1.9768393 , -0.80768518,  1.27865729,  1.74957376,
#        -1.08343796, -0.06586679,  2.96172407,         nan,  2.99441047,
#        -1.51980172,  1.93320293, -2.48490503,         nan, -1.51980172,
#        -1.62769266,         nan, -1.87519576, -2.84587837, -0.12343769,
#        -2.44366864,  1.65657007,  0.83479049, -0.77798333,         nan,
#                nan, -1.01806824, -0.50223055,  2.13076661, -0.86525608,
#                nan, -0.31674066, -0.8216197 ,  3.10230142, -2.09457764,
#        -2.40003227,         nan, -0.51616507, -0.13832494, -1.51677383,
#        -0.33975325,         nan, -1.36400809,  1.99077383,         nan,
#         1.59618013, -1.92003213,  1.88956655, -1.92003213,  2.2295739 ,
#                nan, -2.00730488,         nan, -2.77094146, -1.34525621,
#        -0.38525594,  3.20052414, -2.28974133,         nan, -0.15313954,
#        -1.87639576, -1.24404894, -1.45098197,  1.69440285,  2.07804658,
#         2.14230115,  0.8859299 , -0.41495779,         nan,         nan,
#        -0.66582608,  1.88956655, -1.97678367,  1.21440272,         nan,
#         2.43971215, -1.87639576,  0.37049697, -2.05094126, -2.42185046,
#                nan,         nan, -2.22548676,  2.02047568, -1.92003213,
#        -2.96610516, -1.92003213,  1.58411192,  1.20689968, -0.65802417,
#                nan,         nan,         nan,         nan, -1.74548663,
#        -0.08888497,         nan,  3.03804685,         nan,         nan,
#         1.6071301 , -0.99616521, -1.88951092, -1.45314716, -0.73434695,
#         0.61660861, -1.40610472,         nan,  1.28322246,  1.16326331,
#        -2.57457777,         nan,  0.07599231,         nan,         nan,
#                nan, -0.09855878,         nan, -1.18946259, -2.57457777,
#        -2.13821401,  2.86163503,         nan,  0.18388326, -2.26912314,
#        -2.40003227,         nan, -1.65071084, -2.05094126,         nan,
#         0.95445077, -0.18582594, -1.03988643, -1.27673534, -0.71310086,
#        -1.789123  , -1.53825472,         nan, -0.40401341,  2.14230115,
#         0.46871411, -0.9385943 , -0.60343782, -2.18185039, -1.47376535,
#        -2.13821401, -1.66916385, -0.90889245,  0.05297413,  2.41506938,
#        -2.00730488,  1.58651191, -0.08888497, -1.40951078, -0.69071057,
#         0.75502077,  0.21656966,         nan,  0.8468587 , -2.18185039,
#         0.18388326, -1.17071071, -2.28007311, -0.86525608,         nan,
#        -0.55980145, -2.40003227,         nan,  2.01139202,         nan,
#         0.92206325, -0.90889245,  0.38747676, -0.8216197 ,  1.49683917,
#         2.57866491, -0.86525608, -0.55980145, -2.2822383 ,  1.24311788,
#        -0.68884426,  0.80292345,         nan,         nan, -0.05855522,
#        -4.5940693 ,  1.85799838,  1.49683917, -2.18185039,  3.08168322,
#                nan,         nan,  0.66024499,  2.57866491, -0.61438779,
#        -1.06041977,  3.18957417, -0.64520788, -1.69434722,  1.39081453,
#         2.57866491, -0.07917341, -0.69071057, -0.90702614, -2.70068692,
#                nan, -2.54792677,         nan,  0.42144492,         nan,
#         1.4325846 , -2.05094126, -2.26162011, -2.32974489, -2.3746141 ,
#         0.48933789,  1.89143286, -1.57094112, -1.82525635, -3.37825074,
#         2.96172407, -2.46065402,  2.07804658, -1.96366851, -2.76610865,
#         2.80779676, -1.80223817,  3.58230155,  0.75115615, -0.32768504,
#        -0.22166041, -1.14769253, -0.63313967,         nan,  1.11962693,
#                nan,  1.72292016,  0.39842674,         nan,  2.84048316,
#        -2.68366871,         nan,         nan])

# %%
#Same treatment as before
compared_resuts = compared_resuts.drop(['ticket','cabin'], axis=1)

# %%
compres2 = compared_resuts.dropna()

# %%
compres2.survived[compres2.sex == 'male'].plot(kind='kde')
compres2.survived[compres2.sex == 'female'].plot(kind='kde')
legend(('male','female'))

# %% [markdown]
# females are much more likely to survive than males. While the distribution of males seems realtivly consistent. The female dist looks stacked. Gosh they're ugly

# %% [markdown]
# theres seems to be more struuture here. You can tell by the flat tops and bumps. Lets tease it out:

# %%
# Adjust for class
compres2.survived[compres2.sex == 'female'][compres2.pclass == 3].plot(kind='kde')
compres2.survived[compres2.sex == 'female'][compres2.pclass != 3].plot(kind='kde')

compres2.survived[compres2.sex == 'male'][compres2.pclass == 3].plot(kind='kde')
compres2.survived[compres2.sex == 'male'][compres2.pclass != 3].plot(kind='kde')

title("Who Survied? with respect to Gender and Class"); legend(('female, low class', 'female highclass','male, low class', 'male highclass'),bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2f6bd17a45be> in <module>()
#       1 # Adjust for class
# ----> 2 compres2.survived[compres2.sex=='female'][compres2.pclass==3].plot(kind='kde')
#       3 compres2.survived[compres2.sex=='female'][compres2.pclass!=3].plot(kind='kde')
#       4
#       5 compres2.survived[compres2.sex=='male'][compres2.pclass==3].plot(kind='kde')
#
# NameError: name 'compres2' is not defined

# %%
#female high class definitly has more in it. but the left handed tails of each of the serpations  are strange as well

# %% [markdown]
# # Perphaps certian types of people got on at certian destinations?

# %% [markdown]
# ### Get ready for a big graph:

# %%
compres2.embarked.value_counts()

# %% [markdown]
# As you embark from Q to S (blue to magenta/yellow) the amount of people that survies increases.
# This is consistent acrros genders
# Male distributions are less likely than females.
# Even though the sample from s is much greater than Q and C combined

# %% [markdown]
# not verry illistrative, lets get a better grap

# %%
df = df.sort_index()

# %%
plt.scatter(df.index,res.predict())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8e18b1e53387> in <module>()
# ----> 1 plt.scatter(df.index,res.predict())
#
# NameError: name 'res' is not defined

# %%
plt.plot(np.sort(res.predict()))
plt.plot(res.predict())

# %%
df.columns

# %%
import sklearn.ensemble as ske

# %%
y,x = dmatrices(formula,data=df, return_type='dataframe')

# %%
results = ske.RandomForestClassifier(n_estimators=100).fit(x,y)

# %%
z = results.score(x,y)
z

# %% [markdown]
# ### So that was easy for you huh? Lets try somthing a little more 'fitting' then:

# %%
mytar,mydat = dmatrices(formula,data=df, return_type='dataframe')
mydat.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3a7b8c146030> in <module>()
# ----> 1 mytar,mydat=dmatrices(formula,data=df, return_type='dataframe')
#       2 mydat.columns
#
# NameError: name 'formula' is not defined

# %%
mytar,mydat = dmatrices(formula,data=df, return_type='matrix')

X = np.asarray(mydat)
X = X[:,[6,3]] # why does it expect 2 features. I have 9 man? [3,6] -- too long [2,3] - pretty sweet DBs [3,1] --standard DBs [7,3] -very cool DBs

y = np.asarray(mytar)
y = y.flatten()      # needs to be 1 dimenstional so we flatten. it comes out of dmatirces with a shape. 

n_sample = len(X)

np.random.seed(0)
order = np.random.permutation(n_sample)

X = X[order]
y = y[order].astype(np.float)

# do a cross validation
X_train = X[:.9 * n_sample]
y_train = y[:.9 * n_sample]
X_test = X[.9 * n_sample:]
y_test = y[.9 * n_sample:]

# fit the model
for fig_num, kernel in enumerate(('linear', 'rbf', 'poly')):
    clf = svm.SVC(kernel=kernel, gamma=3)
    clf.fit(X_train, y_train)

    pl.figure(fig_num)
    pl.clf()
    pl.scatter(X[:, 0], X[:, 1], c=y, zorder=10, cmap=pl.cm.Paired)

    # Circle out the test data
    pl.scatter(X_test[:, 0], X_test[:, 1], s=80, facecolors='none', zorder=10)

    pl.axis('tight')
    x_min = X[:, 0].min()
    x_max = X[:, 0].max()
    y_min = X[:, 1].min()
    y_max = X[:, 1].max()

    XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
    Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(XX.shape)
    pl.pcolormesh(XX, YY, Z > 0, cmap=pl.cm.Paired)
    pl.contour(XX, YY, Z, colors=['k', 'k', 'k'], linestyles=['--', '-', '--'],
               levels=[-.5, 0, .5])

    pl.title(kernel)
pl.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-70dd18adaf9f> in <module>()
# ----> 1 mytar,mydat=dmatrices(formula,data=df, return_type='matrix')
#       2
#       3 X=np.asarray(mydat)
#       4 X = X[:,[6,3]] # why does it expect 2 features. I have 9 man? [3,6] -- too long [2,3] - pretty sweet DBs [3,1] --standard DBs [7,3] -very cool DBs
#       5
#
# NameError: name 'formula' is not defined

# %%
clf = svm.SVC(kernel='poly', gamma=3).fit(X_train, y_train)

# %%
y,x = dmatrices(formula,data=test_data, return_type='dataframe')
x.columns

# %%
res_svm = clf.predict(x.ix[:,[6,3]].dropna())
res_svm = DataFrame(res_svm,columns=['Survived'])
res_svm.to_csv(PATH+"svm_poly_63_g10.csv")

# %%
res_svm.Survived.value_counts().plot(kind="bar")

# %%
def age_nan(s,df):
    m=df.age.mean()
    if s == np.nan:
        s=m
    return s

# %%
df.age.mean()

# %%
pwd

# %%
# %%cmd
# git add Titanic.ipynb
# git commit
# Out:
# Microsoft Windows [Version 6.2.9200]
# (c) 2012 Microsoft Corporation. All rights reserved.
#
# C:\Users\Andrew\Documents\Kaggle\Titanic\Dups\Kaggel-Titanic>git add Titanic.ipynb
#
# C:\Users\Andrew\Documents\Kaggle\Titanic\Dups\Kaggel-Titanic>More?

# %%
# !git commit
# Out:
# [master 38e9f7b] Heavily updated first visualizations
#  1 file changed, 337 insertions(+), 76 deletions(-)
